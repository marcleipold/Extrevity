# %%
# import libraries

import pandas as pd
import numpy as np

# %%
# import csv and create a dataframe

reviews_data = pd.read_csv('../Resources/listing-review-import-30000reviews.csv')

reviews_df0 = pd.DataFrame(reviews_data)

reviews_df0.head(5)
# Out:
#                        query                       name  \
# 0  Blue Horizons Dive Center  Blue Horizons Dive Center
# 1  Blue Horizons Dive Center  Blue Horizons Dive Center
# 2  Blue Horizons Dive Center  Blue Horizons Dive Center
# 3  Blue Horizons Dive Center  Blue Horizons Dive Center
# 4  Blue Horizons Dive Center  Blue Horizons Dive Center
#
#                                google_id                     place_id  \
# 0  0x89c6c8a343e41dfb:0xbe9e5c3727f0bee1  ChIJ-x3kQ6PIxokR4b7wJzdcnr4
# 1  0x89c6c8a343e41dfb:0xbe9e5c3727f0bee1  ChIJ-x3kQ6PIxokR4b7wJzdcnr4
# 2  0x89c6c8a343e41dfb:0xbe9e5c3727f0bee1  ChIJ-x3kQ6PIxokR4b7wJzdcnr4
# 3  0x89c6c8a343e41dfb:0xbe9e5c3727f0bee1  ChIJ-x3kQ6PIxokR4b7wJzdcnr4
# 4  0x89c6c8a343e41dfb:0xbe9e5c3727f0bee1  ChIJ-x3kQ6PIxokR4b7wJzdcnr4
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/Blue+Horizon...
# 1  https://www.google.com/maps/place/Blue+Horizon...
# ...

# %%
# Out:
# Index(['query', 'name', 'reviews_link', 'author_title', 'author_image',
#        'review_text', 'review_img_url', 'review_img_urls', 'review_link',
#        'review_rating', 'review_timestamp', 'review_datetime_utc'],
#       dtype='object')

# %%
# drop useless columns

reviews_df0.drop(['google_id', 'rating', 'place_id', 'location_link', 'reviews_per_score', 'reviews', 'review_id', 'author_link', 'author_id',
       'owner_answer', 'owner_answer_timestamp',
       'owner_answer_timestamp_datetime_utc', 'review_likes',
       'reviews_id'], axis=1, inplace=True)
reviews_df = reviews_df

# %%
reviews_df
# Out:
#                                   query                       name  \
# 0             Blue Horizons Dive Center  Blue Horizons Dive Center
# 1             Blue Horizons Dive Center  Blue Horizons Dive Center
# 2             Blue Horizons Dive Center  Blue Horizons Dive Center
# 3             Blue Horizons Dive Center  Blue Horizons Dive Center
# 4             Blue Horizons Dive Center  Blue Horizons Dive Center
# ...                                 ...                        ...
# 30471                    Skydive DeLand       Skydive DeLand, Inc.
# 30472                    Skydive DeLand       Skydive DeLand, Inc.
# 30473                    Skydive DeLand       Skydive DeLand, Inc.
# 30474                    Skydive DeLand       Skydive DeLand, Inc.
# 30475  Freefall Adventures Florida, Inc        Adventure Skydiving
#
#                                             reviews_link  \
# 0      https://search.google.com/local/reviews?placei...
# ...

# %%
# Import Users (review writers)

reviews_df =
