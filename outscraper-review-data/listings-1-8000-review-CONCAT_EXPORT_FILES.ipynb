# %% [markdown]
# # Extrevity.com review import from Outscraper

# %%
# import libraries

import pandas as pd
import numpy as np

# %%
#import CSVs

review_export_1_1000 = pd. read_excel('../Resources/listings-reviews-1-1000 (2).xlsx')
review_export_1000_2000 = pd.read_excel("../Resources/listings-reviews-1000-2000.xlsx")
review_export_2000_8000 = pd.read_csv('../Resources/listing-reviews-2000-8000.csv')

# %%
df1 = pd.DataFrame(review_export_1_1000)
df2 = pd.DataFrame(review_export_1000_2000)
df3 = pd.DataFrame(review_export_2000_8000)

# %%
# concat the 3 dataframes

merged_df = pd.concat([df1, df2, df3], axis=0)

merged_df
# Out:
#                                   query                       name  \
# 0             Blue Horizons Dive Center  Blue Horizons Dive Center
# 1             Blue Horizons Dive Center  Blue Horizons Dive Center
# 2             Blue Horizons Dive Center  Blue Horizons Dive Center
# 3             Blue Horizons Dive Center  Blue Horizons Dive Center
# 4             Blue Horizons Dive Center  Blue Horizons Dive Center
# ...                                 ...                        ...
# 22211                    Skydive DeLand       Skydive DeLand, Inc.
# 22212                    Skydive DeLand       Skydive DeLand, Inc.
# 22213                    Skydive DeLand       Skydive DeLand, Inc.
# 22214                    Skydive DeLand       Skydive DeLand, Inc.
# 22215  Freefall Adventures Florida, Inc        Adventure Skydiving
#
#                                    google_id                     place_id  \
# 0      0x89c6c8a343e41dfb:0xbe9e5c3727f0bee1  ChIJ-x3kQ6PIxokR4b7wJzdcnr4
# ...

# %%
# save new merged dataframe to csv

merged_df.to_csv("listing-review-import-30000reviews.csv", index=False)
